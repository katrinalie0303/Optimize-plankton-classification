# %% [markdown]
# ![datahacker.png](data:image/png;base64,...)
# # Siamese Networks

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random
from PIL import Image
import PIL.ImageOps

import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
import torchvision.utils
import torch
from torch.autograd import Variable
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
# Creating some helper functions
def imshow(img, text=None):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})

    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
class SiameseNetworkDataset(Dataset):
    def __init__(self,imageFolderDataset,transform=None):
        self.imageFolderDataset = imageFolderDataset
        self.transform = transform

    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)

        #We need to approximately 50% of images to be in the same class
        should_get_same_class = random.randint(0,1)
        if should_get_same_class:
            while True:
                #Look untill the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs)
                if img0_tuple[1] == img1_tuple[1]:
                    break
        else:

            while True:
                #Look untill a different class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs)
                if img0_tuple[1] != img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])

        img0 = img0.convert("L")
        img1 = img1.convert("L")

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)

        return img0, img1, torch.from_numpy(np.array([int(img1_tuple[1] != img0_tuple[1])], dtype=np.float32))

    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %% [markdown]
# Download the dataset from our [GitHub](https://github.com/maticvl/dataHacker/blob/master/DATA/at%26t.zip) profile, just by running the code below.

# %%
# Load the training dataset
folder_dataset = datasets.ImageFolder(root="../../../organized_dataset_v7/dataset/train")

# %%
# Resize the images and transform to tensors
transformation = transforms.Compose([transforms.Resize((100,100)),
                                     transforms.ToTensor()
                                    ])

# Initialize the network
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transformation)

# %%
# Create a simple dataloader just for simple visualization
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=2,
                        batch_size=8)

# Extract one batch
example_batch = next(iter(vis_dataloader))

# Example batch is a list containing 2x8 images, indexes 0 and 1, an also the label
# If the label is 1, it means that it is not the same person, label is 0, same person in both images
concatenated = torch.cat((example_batch[0], example_batch[1]),0)

imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy().reshape(-1))
# Out:
# [1. 1. 0. 1. 1. 0. 1. 1.]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#create the Siamese Neural Network
class SiameseNetwork(nn.Module):

    def __init__(self):
        super(SiameseNetwork, self).__init__()

        # Setting up the Sequential of CNN Layers
        self.cnn1 = nn.Sequential(
            nn.Conv2d(1, 96, kernel_size=11,stride=4),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(3, stride=2),

            nn.Conv2d(96, 256, kernel_size=5, stride=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, stride=2),

            nn.Conv2d(256, 384, kernel_size=3,stride=1),
            nn.ReLU(inplace=True)
        )

        # Setting up the Fully Connected Layers
        self.fc1 = nn.Sequential(
            nn.Linear(384, 1024),
            nn.ReLU(inplace=True),

            nn.Linear(1024, 256),
            nn.ReLU(inplace=True),

            nn.Linear(256,2)
        )

    def forward_once(self, x):
        # This function will be called for both images
        # It's output is used to determine the similiarity
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        # In this function we pass in both images and obtain both vectors
        # which are returned
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)

        return output1, output2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Define the Contrastive Loss Function
class ContrastiveLoss(torch.nn.Module):
    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
      # Calculate the euclidian distance and calculate the contrastive loss
      euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)

      loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                    (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


      return loss_contrastive

# %%
# Load the training dataset
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=64)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(), lr = 0.0005 )

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
counter = []
loss_history = []
iteration_number= 0

# Iterate throught the epochs
for epoch in range(30):

    # Iterate over batches
    for i, (img0, img1, label) in enumerate(train_dataloader, 0):

        # Send the images and labels to CUDA
        img0, img1, label = img0.cuda(), img1.cuda(), label.cuda()

        # Zero the gradients
        optimizer.zero_grad()

        # Pass in the two images into the network and obtain two outputs
        output1, output2 = net(img0, img1)

        # Pass the outputs of the networks and label into the loss function
        loss_contrastive = criterion(output1, output2, label)

        # Calculate the backpropagation
        loss_contrastive.backward()

        # Optimize
        optimizer.step()

        # Every 10 batches print out the loss
        if i % 10 == 0 :
            print(f"Epoch number {epoch}\n Current loss {loss_contrastive.item()}\n")
            iteration_number += 10

            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())

show_plot(counter, loss_history)
# Out:
# Epoch number 0
#  Current loss 2.0579538345336914
#
# Epoch number 0
#  Current loss 1.3247582912445068
#
# Epoch number 0
#  Current loss 0.7729817628860474
#
# Epoch number 0
#  Current loss 0.8005515933036804
#
# Epoch number 0
#  Current loss 0.8111867308616638
#
# Epoch number 0
#  Current loss 0.9348289966583252
#
# Epoch number 0
#  Current loss 1.0165259838104248
#
# Epoch number 0
#  Current loss 0.8586524724960327
#
# Epoch number 0
#  Current loss 0.71346515417099
#
# Epoch number 0
#  Current loss 0.7730899453163147
#
# Epoch number 0
#  Current loss 0.9040448665618896
#
# Epoch number 0
#  Current loss 0.8762437105178833
#
# Epoch number 0
#  Current loss 0.6366221904754639
#
# Epoch number 0
#  Current loss 0.7905739545822144
#
# Epoch number 0
#  Current loss 0.7630695104598999
#
# Epoch number 0
#  Current loss 0.8328237533569336
#
# Epoch number 0
#  Current loss 1.0372036695480347
#
# Epoch number 0
#  Current loss 1.031320333480835
#
# Epoch number 0
#  Current loss 0.7218719720840454
#
# Epoch number 0
#  Current loss 0.7664364576339722
#
# Epoch number 0
#  Current loss 1.0337309837341309
#
# Epoch number 0
#  Current loss 0.6049215793609619
#
# Epoch number 0
#  Current loss 0.9826645255088806
#
# Epoch number 0
#  Current loss 0.8252757787704468
#
# Epoch number 0
#  Current loss 0.6854703426361084
#
# Epoch number 0
#  Current loss 1.0172399282455444
#
# Epoch number 0
#  Current loss 1.0712409019470215
#
# Epoch number 0
#  Current loss 0.6920900344848633
#
# Epoch number 0
#  Current loss 0.8590801954269409
#
# Epoch number 0
#  Current loss 0.5523743629455566
#
# Epoch number 0
#  Current loss 0.9363129734992981
#
# Epoch number 0
#  Current loss 0.6957341432571411
#
# Epoch number 0
#  Current loss 0.7506823539733887
#
# Epoch number 0
#  Current loss 0.723628044128418
#
# Epoch number 0
#  Current loss 1.024351716041565
#
# Epoch number 0
#  Current loss 0.7258216142654419
#
# Epoch number 0
#  Current loss 0.9320420026779175
#
# Epoch number 0
#  Current loss 0.7837196588516235
#
# Epoch number 0
#  Current loss 0.8039339780807495
#
# Epoch number 0
#  Current loss 0.8578200936317444
#
# Epoch number 0
#  Current loss 0.8261706829071045
#
# Epoch number 0
#  Current loss 0.8561244010925293
#
# Epoch number 0
#  Current loss 0.9863163232803345
#
# Epoch number 0
#  Current loss 0.7097703218460083
#
# Epoch number 0
#  Current loss 0.894123911857605
#
# Epoch number 0
#  Current loss 0.8510135412216187
#
# Epoch number 0
#  Current loss 0.5670271515846252
#
# Epoch number 0
#  Current loss 0.5646789073944092
#
# Epoch number 0
#  Current loss 0.7745770215988159
#
# Epoch number 0
#  Current loss 0.6606963872909546
#
# Epoch number 0
#  Current loss 0.7922966480255127
#
# Epoch number 0
#  Current loss 0.7101298570632935
#
# Epoch number 0
#  Current loss 1.0502099990844727
#
# Epoch number 0
#  Current loss 0.805656909942627
#
# Epoch number 0
#  Current loss 0.7340768575668335
#
# Epoch number 0
#  Current loss 0.8530545234680176
#
# Epoch number 0
#  Current loss 0.5936137437820435
#
# Epoch number 0
#  Current loss 0.7602009177207947
#
# Epoch number 0
#  Current loss 0.6884030103683472
#
# Epoch number 0
#  Current loss 0.8776290416717529
#
# Epoch number 0
#  Current loss 0.6667182445526123
#
# Epoch number 0
#  Current loss 0.6546599864959717
#
# Epoch number 0
#  Current loss 0.7361737489700317
#
# Epoch number 0
#  Current loss 0.7410881519317627
#
# Epoch number 0
#  Current loss 0.781468391418457
#
# Epoch number 0
#  Current loss 0.901441216468811
#
# Epoch number 0
#  Current loss 0.5557975769042969
#
# Epoch number 0
#  Current loss 0.6598095893859863
#
# Epoch number 0
#  Current loss 0.6798253059387207
#
# Epoch number 0
#  Current loss 0.6799072623252869
#
# Epoch number 0
#  Current loss 0.8396580219268799
#
# Epoch number 0
#  Current loss 0.9236696362495422
#
# Epoch number 0
#  Current loss 0.8034013509750366
#
# Epoch number 0
#  Current loss 0.743024468421936
#
# Epoch number 0
#  Current loss 0.8797169923782349
#
# Epoch number 0
#  Current loss 0.9478477835655212
#
# Epoch number 0
#  Current loss 0.8700939416885376
#
# Epoch number 0
#  Current loss 0.6816781163215637
#
# Epoch number 0
#  Current loss 0.9333522319793701
#
# Epoch number 0
#  Current loss 0.9320853352546692
#
# Epoch number 0
#  Current loss 0.6522517800331116
#
# Epoch number 0
#  Current loss 0.7396118640899658
#
# Epoch number 0
#  Current loss 0.7188658714294434
#
# Epoch number 0
#  Current loss 0.8374999761581421
#
# Epoch number 0
#  Current loss 0.7800310850143433
#
# Epoch number 0
#  Current loss 1.1308526992797852
#
# Epoch number 0
#  Current loss 0.8406027555465698
#
# Epoch number 0
#  Current loss 0.7723157405853271
#
# Epoch number 0
#  Current loss 0.5582302808761597
#
# Epoch number 0
#  Current loss 0.891173243522644
#
# Epoch number 0
#  Current loss 0.6136162281036377
#
# Epoch number 0
#  Current loss 0.6242557168006897
#
# Epoch number 0
#  Current loss 0.7481892704963684
#
# Epoch number 0
#  Current loss 0.7383836507797241
#
# Epoch number 0
#  Current loss 0.8383420705795288
#
# Epoch number 0
#  Current loss 0.582629919052124
#
# Epoch number 0
#  Current loss 0.8294855356216431
#
# Epoch number 0
#  Current loss 0.6842234134674072
#
# Epoch number 0
#  Current loss 0.7353484630584717
#
# Epoch number 0
#  Current loss 0.7747396230697632
#
# Epoch number 0
#  Current loss 1.1845014095306396
#
# Epoch number 0
#  Current loss 0.7610235214233398
#
# Epoch number 0
#  Current loss 0.7012874484062195
#
# Epoch number 0
#  Current loss 0.586773157119751
#
# Epoch number 0
#  Current loss 0.6884092688560486
#
# Epoch number 0
#  Current loss 0.7254247665405273
#
# Epoch number 0
#  Current loss 0.9778223633766174
#
# Epoch number 0
#  Current loss 0.7199446558952332
#
# Epoch number 0
#  Current loss 0.568956196308136
#
# Epoch number 0
#  Current loss 0.7166097164154053
#
# Epoch number 0
#  Current loss 0.754147469997406
#
# Epoch number 0
#  Current loss 0.6992499232292175
#
# Epoch number 0
#  Current loss 0.8819730877876282
#
# Epoch number 0
#  Current loss 0.8602718114852905
#
# Epoch number 0
#  Current loss 0.7484258413314819
#
# Epoch number 0
#  Current loss 0.6661967039108276
#
# Epoch number 0
#  Current loss 0.6358844041824341
#
# Epoch number 0
#  Current loss 0.7134861946105957
#
# Epoch number 0
#  Current loss 0.6516330242156982
#
# Epoch number 0
#  Current loss 0.8182299137115479
#
# Epoch number 0
#  Current loss 0.8896870017051697
#
# Epoch number 0
#  Current loss 0.8005850315093994
#
# Epoch number 0
#  Current loss 0.8923873901367188
#
# Epoch number 0
#  Current loss 0.5221594572067261
#
# Epoch number 0
#  Current loss 0.7753595113754272
#
# Epoch number 0
#  Current loss 0.9338662028312683
#
# Epoch number 0
#  Current loss 0.6800116300582886
#
# Epoch number 0
#  Current loss 0.9186147451400757
#
# Epoch number 0
#  Current loss 0.8104793429374695
#
# Epoch number 0
#  Current loss 0.5921546220779419
#
# Epoch number 0
#  Current loss 0.9026952981948853
#
# Epoch number 0
#  Current loss 0.7450641393661499
#
# Epoch number 0
#  Current loss 0.8049510717391968
#
# Epoch number 0
#  Current loss 0.901239275932312
#
# Epoch number 0
#  Current loss 0.7178819179534912
#
# Epoch number 0
#  Current loss 0.6729682683944702
#
# Epoch number 0
#  Current loss 0.5587953329086304
#
# Epoch number 0
#  Current loss 0.7553666830062866
#
# Epoch number 0
#  Current loss 0.7259453535079956
#
# Epoch number 0
#  Current loss 0.8504934310913086
#
# Epoch number 0
#  Current loss 0.6029043197631836
#
# Epoch number 0
#  Current loss 0.9382271766662598
#
# Epoch number 0
#  Current loss 0.9497414827346802
#
# Epoch number 0
#  Current loss 0.6673672795295715
#
# Epoch number 0
#  Current loss 0.8140117526054382
#
# Epoch number 0
#  Current loss 0.7373278141021729
#
# Epoch number 0
#  Current loss 0.8658106327056885
#
# Epoch number 0
#  Current loss 1.020402431488037
#
# Epoch number 0
#  Current loss 0.5557723045349121
#
# Epoch number 0
#  Current loss 0.8029654622077942
#
# Epoch number 0
#  Current loss 0.7446420192718506
#
# Epoch number 0
#  Current loss 0.6730872988700867
#
# Epoch number 0
#  Current loss 0.700874924659729
#
# Epoch number 0
#  Current loss 0.6385568380355835
#
# Epoch number 0
#  Current loss 0.7966384291648865
#
# Epoch number 0
#  Current loss 0.5402296781539917
#
# Epoch number 0
#  Current loss 0.8564225435256958
#
# Epoch number 0
#  Current loss 0.8491233587265015
#
# Epoch number 0
#  Current loss 0.7974293828010559
#
# Epoch number 0
#  Current loss 0.7956019639968872
#
# Epoch number 0
#  Current loss 0.7220054268836975
#
# Epoch number 0
#  Current loss 0.7211623787879944
#
# Epoch number 0
#  Current loss 0.7698851823806763
#
# Epoch number 0
#  Current loss 0.816045880317688
#
# Epoch number 0
#  Current loss 0.8730193376541138
#
# Epoch number 0
#  Current loss 0.8685777187347412
#
# Epoch number 0
#  Current loss 0.911207914352417
#
# Epoch number 0
#  Current loss 0.635106086730957
#
# Epoch number 0
#  Current loss 0.7308820486068726
#
# Epoch number 0
#  Current loss 0.5551124811172485
#
# Epoch number 0
#  Current loss 0.7965497970581055
#
# Epoch number 0
#  Current loss 0.8143592476844788
#
# Epoch number 0
#  Current loss 0.657016396522522
#
# Epoch number 0
#  Current loss 0.7053671479225159
#
# Epoch number 0
#  Current loss 0.6666271686553955
#
# Epoch number 0
#  Current loss 0.5421717166900635
#
# Epoch number 0
#  Current loss 0.5488784313201904
#
# Epoch number 0
#  Current loss 0.7404098510742188
#
# Epoch number 0
#  Current loss 0.522405207157135
#
# Epoch number 0
#  Current loss 0.8417043089866638
#
# Epoch number 0
#  Current loss 0.7681450843811035
#
# Epoch number 0
#  Current loss 0.6273612380027771
#
# Epoch number 0
#  Current loss 0.5969387292861938
#
# Epoch number 0
#  Current loss 0.976692795753479
#
# Epoch number 0
#  Current loss 0.8343653082847595
#
# Epoch number 0
#  Current loss 0.6655016541481018
#
# Epoch number 0
#  Current loss 0.872744083404541
#
# Epoch number 0
#  Current loss 0.7344831228256226
#
# Epoch number 0
#  Current loss 0.7907272577285767
#
# Epoch number 0
#  Current loss 0.7211847305297852
#
# Epoch number 0
#  Current loss 0.6984233856201172
#
# Epoch number 0
#  Current loss 0.6493503451347351
#
# Epoch number 0
#  Current loss 0.7510213851928711
#
# Epoch number 0
#  Current loss 0.8040676116943359
#
# Epoch number 0
#  Current loss 0.7119780778884888
#
# Epoch number 0
#  Current loss 0.6537518501281738
#
# Epoch number 0
#  Current loss 0.7382900714874268
#
# Epoch number 0
#  Current loss 0.7168409824371338
#
# Epoch number 0
#  Current loss 0.6337217092514038
#
# Epoch number 0
#  Current loss 0.779790461063385
#
# Epoch number 0
#  Current loss 0.7546612620353699
#
# Epoch number 0
#  Current loss 0.6853078603744507
#
# Epoch number 0
#  Current loss 0.8545361161231995
#
# Epoch number 0
#  Current loss 0.6462175846099854
#
# Epoch number 0
#  Current loss 0.712274432182312
#
# Epoch number 0
#  Current loss 0.7238808870315552
#
# Epoch number 0
#  Current loss 0.7175867557525635
#
# Epoch number 0
#  Current loss 0.7224200367927551
#
# Epoch number 0
#  Current loss 0.629944920539856
#
# Epoch number 0
#  Current loss 0.5869061946868896
#
# Epoch number 0
#  Current loss 0.7108902931213379
#
# Epoch number 0
#  Current loss 0.719724178314209
#
# Epoch number 0
#  Current loss 0.8791077136993408
#
# Epoch number 0
#  Current loss 0.6881778240203857
#
# Epoch number 0
#  Current loss 0.6740462779998779
#
# Epoch number 0
#  Current loss 0.6896198987960815
#
# Epoch number 0
#  Current loss 0.6860086917877197
#
# Epoch number 0
#  Current loss 0.9700888395309448
#
# Epoch number 0
#  Current loss 0.7437458038330078
#
# Epoch number 0
#  Current loss 0.6739813089370728
#
# Epoch number 0
#  Current loss 0.58670973777771
#
# Epoch number 0
#  Current loss 0.8133722543716431
#
# Epoch number 0
#  Current loss 0.6979447603225708
#
# Epoch number 0
#  Current loss 0.59563148021698
#
# Epoch number 0
#  Current loss 0.7627871036529541
#
# Epoch number 0
#  Current loss 0.7474308013916016
#
# Epoch number 0
#  Current loss 0.7672612071037292
#
# Epoch number 0
#  Current loss 0.7313997745513916
#
# Epoch number 0
#  Current loss 0.660115122795105
#
# Epoch number 0
#  Current loss 0.7053520083427429
#
# Epoch number 0
#  Current loss 0.818116307258606
#
# Epoch number 0
#  Current loss 0.5656375288963318
#
# Epoch number 0
#  Current loss 0.4969877302646637
#
# Epoch number 0
#  Current loss 0.6786278486251831
#
# Epoch number 0
#  Current loss 0.605960488319397
#
# Epoch number 0
#  Current loss 0.6702619791030884
#
# Epoch number 0
#  Current loss 0.45395803451538086
#
# Epoch number 0
#  Current loss 0.8417699337005615
#
# Epoch number 0
#  Current loss 0.6549796462059021
#
# Epoch number 0
#  Current loss 0.7773234248161316
#
# Epoch number 0
#  Current loss 0.6507977247238159
#
# Epoch number 0
#  Current loss 0.8529988527297974
#
# Epoch number 0
#  Current loss 0.7467606663703918
#
# Epoch number 0
#  Current loss 0.7039952278137207
#
# Epoch number 0
#  Current loss 0.648282527923584
#
# Epoch number 0
#  Current loss 0.7639466524124146
#
# Epoch number 0
#  Current loss 0.5294675827026367
#
# Epoch number 0
#  Current loss 0.5652234554290771
#
# Epoch number 0
#  Current loss 0.705165445804596
#
# Epoch number 0
#  Current loss 0.6099520921707153
#
# Epoch number 0
#  Current loss 0.7190154790878296
#
# Epoch number 0
#  Current loss 0.9027692675590515
#
# Epoch number 0
#  Current loss 0.6945793032646179
#
# Epoch number 0
#  Current loss 0.9654101133346558
#
# Epoch number 0
#  Current loss 0.5960185527801514
#
# Epoch number 0
#  Current loss 0.7057890892028809
#
# Epoch number 0
#  Current loss 0.6353322267532349
#
# Epoch number 0
#  Current loss 0.5589472055435181
#
# Epoch number 0
#  Current loss 0.8726843595504761
#
# Epoch number 0
#  Current loss 0.4655489921569824
#
# Epoch number 0
#  Current loss 0.6705924272537231
#
# Epoch number 0
#  Current loss 0.6052396893501282
#
# Epoch number 0
#  Current loss 0.6304226517677307
#
# Epoch number 0
#  Current loss 0.8108304142951965
#
# Epoch number 0
#  Current loss 0.6368331909179688
#
# Epoch number 0
#  Current loss 0.584580659866333
#
# Epoch number 0
#  Current loss 0.9108229875564575
#
# Epoch number 0
#  Current loss 0.7072324752807617
#
# Epoch number 0
#  Current loss 0.783284604549408
#
# Epoch number 0
#  Current loss 0.728442907333374
#
# Epoch number 0
#  Current loss 0.6814886331558228
#
# Epoch number 0
#  Current loss 0.8066878318786621
#
# Epoch number 0
#  Current loss 0.5680452585220337
#
# Epoch number 0
#  Current loss 0.6847780346870422
#
# Epoch number 0
#  Current loss 0.821312427520752
#
# Epoch number 0
#  Current loss 0.6013429164886475
#
# Epoch number 0
#  Current loss 0.573406457901001
#
# Epoch number 0
#  Current loss 0.7333083152770996
#
# Epoch number 0
#  Current loss 0.6746125221252441
#
# Epoch number 0
#  Current loss 0.6520913243293762
#
# Epoch number 0
#  Current loss 0.7693991661071777
#
# Epoch number 0
#  Current loss 0.5524346828460693
#
# Epoch number 0
#  Current loss 0.7658170461654663
#
# Epoch number 0
#  Current loss 0.7027813196182251
#
# Epoch number 0
#  Current loss 0.5602179765701294
#
# Epoch number 0
#  Current loss 0.8488300442695618
#
# Epoch number 0
#  Current loss 0.65162193775177
#
# Epoch number 0
#  Current loss 0.8517616987228394
#
# Epoch number 0
#  Current loss 0.573745608329773
#
# Epoch number 0
#  Current loss 0.5098258852958679
#
# Epoch number 0
#  Current loss 0.7839230298995972
#
# Epoch number 0
#  Current loss 0.6184459328651428
#
# Epoch number 0
#  Current loss 0.4814381003379822
#
# Epoch number 0
#  Current loss 0.6556744575500488
#
# Epoch number 0
#  Current loss 0.7535719871520996
#
# Epoch number 0
#  Current loss 0.8193953633308411
#
# Epoch number 0
#  Current loss 0.7769572734832764
#
# Epoch number 0
#  Current loss 0.8611184358596802
#
# Epoch number 0
#  Current loss 0.5413298606872559
#
# Epoch number 0
#  Current loss 0.5609583854675293
#
# Epoch number 0
#  Current loss 0.7061307430267334
#
# Epoch number 0
#  Current loss 0.634891152381897
#
# Epoch number 0
#  Current loss 0.7351064682006836
#
# Epoch number 0
#  Current loss 0.5887935757637024
#
# Epoch number 0
#  Current loss 0.8514539003372192
#
# Epoch number 0
#  Current loss 0.7127246856689453
#
# Epoch number 0
#  Current loss 0.6548362970352173
#
# Epoch number 0
#  Current loss 0.6657731533050537
#
# Epoch number 0
#  Current loss 0.6957393884658813
#
# Epoch number 0
#  Current loss 0.5470893383026123
#
# Epoch number 0
#  Current loss 0.7306458950042725
#
# Epoch number 0
#  Current loss 0.6924437284469604
#
# Epoch number 0
#  Current loss 0.5399051904678345
#
# Epoch number 0
#  Current loss 0.7040168642997742
#
# Epoch number 0
#  Current loss 0.5448938608169556
#
# Epoch number 0
#  Current loss 0.5818840265274048
#
# Epoch number 0
#  Current loss 0.48135602474212646
#
# Epoch number 0
#  Current loss 0.843658447265625
#
# Epoch number 0
#  Current loss 0.6491082906723022
#
# Epoch number 0
#  Current loss 0.8583776950836182
#
# Epoch number 0
#  Current loss 0.6464658379554749
#
# Epoch number 0
#  Current loss 0.8993043899536133
#
# Epoch number 0
#  Current loss 0.8513838052749634
#
# Epoch number 0
#  Current loss 0.6383775472640991
#
# Epoch number 0
#  Current loss 0.6452571153640747
#
# Epoch number 0
#  Current loss 0.5302029848098755
#
# Epoch number 0
#  Current loss 0.8047436475753784
#
# Epoch number 0
#  Current loss 0.7129760384559631
#
# Epoch number 0
#  Current loss 0.4807630479335785
#
# Epoch number 0
#  Current loss 0.7680186629295349
#
# Epoch number 0
#  Current loss 0.7237048149108887
#
# Epoch number 0
#  Current loss 0.776901364326477
#
# Epoch number 0
#  Current loss 0.727268636226654
#
# Epoch number 0
#  Current loss 0.7199017405509949
#
# Epoch number 0
#  Current loss 0.650026261806488
#
# Epoch number 0
#  Current loss 0.8753982782363892
#
# Epoch number 0
#  Current loss 0.8057310581207275
#
# Epoch number 0
#  Current loss 0.7297480702400208
#
# Epoch number 0
#  Current loss 0.7237529754638672
#
# Epoch number 0
#  Current loss 0.646371066570282
#
# Epoch number 0
#  Current loss 0.6977383494377136
#
# Epoch number 0
#  Current loss 0.8514341115951538
#
# Epoch number 0
#  Current loss 0.550714373588562
#
# Epoch number 0
#  Current loss 0.6459523439407349
#
# Epoch number 0
#  Current loss 0.6697913408279419
#
# Epoch number 0
#  Current loss 0.5265650153160095
#
# Epoch number 0
#  Current loss 0.5389978885650635
#
# Epoch number 0
#  Current loss 0.8080564737319946
#
# Epoch number 0
#  Current loss 0.6349385976791382
#
# Epoch number 0
#  Current loss 0.7753984928131104
#
# Epoch number 0
#  Current loss 0.6224734783172607
#
# Epoch number 0
#  Current loss 0.7217867374420166
#
# Epoch number 0
#  Current loss 0.7302128076553345
#
# Epoch number 0
#  Current loss 0.6214316487312317
#
# Epoch number 0
#  Current loss 0.7696756720542908
#
# Epoch number 0
#  Current loss 0.576087474822998
#
# Epoch number 0
#  Current loss 0.5703694820404053
#
# Epoch number 0
#  Current loss 0.6058577299118042
#
# Epoch number 0
#  Current loss 0.5443121790885925
#
# Epoch number 0
#  Current loss 0.7529445290565491
#
# Epoch number 0
#  Current loss 0.5199229717254639
#
# Epoch number 0
#  Current loss 0.7165932655334473
#
# Epoch number 0
#  Current loss 0.6658769845962524
#
# Epoch number 0
#  Current loss 0.9549976587295532
#
# Epoch number 0
#  Current loss 0.6476077437400818
#
# Epoch number 0
#  Current loss 0.7996952533721924
#
# Epoch number 0
#  Current loss 0.5180673599243164
#
# Epoch number 0
#  Current loss 0.5757807493209839
#
# Epoch number 0
#  Current loss 0.7652730345726013
#
# Epoch number 0
#  Current loss 0.6036704778671265
#
# Epoch number 0
#  Current loss 0.6776977777481079
#
# Epoch number 0
#  Current loss 0.5758863091468811
#
# Epoch number 0
#  Current loss 0.601529598236084
#
# Epoch number 0
#  Current loss 0.6824098825454712
#
# Epoch number 0
#  Current loss 0.6600937247276306
#
# Epoch number 0
#  Current loss 0.6395357847213745
#
# Epoch number 0
#  Current loss 0.799321174621582
#
# Epoch number 0
#  Current loss 0.7248572707176208
#
# Epoch number 0
#  Current loss 0.7440145015716553
#
# Epoch number 0
#  Current loss 0.693549394607544
#
# Epoch number 0
#  Current loss 0.7811857461929321
#
# Epoch number 0
#  Current loss 0.6040093898773193
#
# Epoch number 0
#  Current loss 0.7810813188552856
#
# Epoch number 0
#  Current loss 0.6264592409133911
#
# Epoch number 0
#  Current loss 0.6334888935089111
#
# Epoch number 0
#  Current loss 0.6904767155647278
#
# Epoch number 0
#  Current loss 0.5798333287239075
#
# Epoch number 0
#  Current loss 0.7388415336608887
#
# Epoch number 0
#  Current loss 0.5798650979995728
#
# Epoch number 0
#  Current loss 0.44630521535873413
#
# Epoch number 0
#  Current loss 0.7002718448638916
#
# Epoch number 0
#  Current loss 0.64776611328125
#
# Epoch number 0
#  Current loss 0.7052323222160339
#
# Epoch number 0
#  Current loss 0.7947840690612793
#
# Epoch number 0
#  Current loss 0.7542778253555298
#
# Epoch number 0
#  Current loss 0.654222846031189
#
# Epoch number 0
#  Current loss 0.8146823048591614
#
# Epoch number 0
#  Current loss 0.6780574917793274
#
# Epoch number 0
#  Current loss 0.6915501952171326
#
# Epoch number 0
#  Current loss 0.6548600196838379
#
# Epoch number 0
#  Current loss 0.5935747623443604
#
# Epoch number 0
#  Current loss 0.7491458654403687
#
# Epoch number 0
#  Current loss 0.6492906808853149
#
# Epoch number 0
#  Current loss 0.6881964206695557
#
# Epoch number 0
#  Current loss 0.5109063386917114
#
# Epoch number 0
#  Current loss 0.6174994707107544
#
# Epoch number 0
#  Current loss 0.7277121543884277
#
# Epoch number 0
#  Current loss 0.5285472869873047
#
# Epoch number 0
#  Current loss 0.5112230777740479
#
# Epoch number 0
#  Current loss 0.7140989303588867
#
# Epoch number 0
#  Current loss 0.7813681364059448
#
# Epoch number 0
#  Current loss 0.7613073587417603
#
# Epoch number 0
#  Current loss 0.38600170612335205
#
# Epoch number 0
#  Current loss 0.6172606945037842
#
# Epoch number 0
#  Current loss 0.6463558673858643
#
# Epoch number 0
#  Current loss 0.6854655742645264
#
# Epoch number 0
#  Current loss 0.7078852653503418
#
# Epoch number 0
#  Current loss 0.7418810129165649
#
# Epoch number 0
#  Current loss 0.8473196029663086
#
# Epoch number 0
#  Current loss 0.6307774782180786
#
# Epoch number 0
#  Current loss 0.6257798671722412
#
# Epoch number 0
#  Current loss 0.600002646446228
#
# Epoch number 0
#  Current loss 0.6133071184158325
#
# Epoch number 0
#  Current loss 0.6228451728820801
#
# Epoch number 0
#  Current loss 0.7776617407798767
#
# Epoch number 0
#  Current loss 0.35947078466415405
#
# Epoch number 0
#  Current loss 0.5498976111412048
#
# Epoch number 0
#  Current loss 0.449634850025177
#
# Epoch number 0
#  Current loss 0.7120625972747803
#
# Epoch number 0
#  Current loss 0.46355924010276794
#
# Epoch number 0
#  Current loss 0.6292608976364136
#
# Epoch number 0
#  Current loss 0.6432163715362549
#
# Epoch number 0
#  Current loss 0.7629204392433167
#
# Epoch number 0
#  Current loss 0.8259516358375549
#
# Epoch number 0
#  Current loss 0.6672143936157227
#
# Epoch number 0
#  Current loss 0.957205593585968
#
# Epoch number 0
#  Current loss 0.6620683073997498
#
# Epoch number 0
#  Current loss 0.6834416389465332
#
# Epoch number 0
#  Current loss 0.5449279546737671
#
# Epoch number 0
#  Current loss 0.7511241436004639
#
# Epoch number 0
#  Current loss 0.5935013294219971
#
# Epoch number 0
#  Current loss 0.6268752813339233
#
# Epoch number 0
#  Current loss 0.6930097341537476
#
# Epoch number 0
#  Current loss 0.6368457078933716
#
# Epoch number 0
#  Current loss 0.6260418891906738
#
# Epoch number 0
#  Current loss 0.6663999557495117
#
# Epoch number 0
#  Current loss 0.5613460540771484
#
# Epoch number 0
#  Current loss 0.4772421717643738
#
# Epoch number 0
#  Current loss 0.602962851524353
#
# Epoch number 0
#  Current loss 0.6882696151733398
#
# Epoch number 0
#  Current loss 0.555689811706543
#
# Epoch number 0
#  Current loss 0.6214720606803894
#
# Epoch number 0
#  Current loss 0.6192703247070312
#
# Epoch number 0
#  Current loss 0.7394179105758667
#
# Epoch number 0
#  Current loss 0.6568998098373413
#
# Epoch number 0
#  Current loss 0.6891042590141296
#
# Epoch number 0
#  Current loss 0.5524001121520996
#
# Epoch number 0
#  Current loss 0.7585731744766235
#
# Epoch number 0
#  Current loss 0.586626410484314
#
# Epoch number 0
#  Current loss 0.578898012638092
#
# Epoch number 0
#  Current loss 0.7118171453475952
#
# Epoch number 0
#  Current loss 0.5870967507362366
#
# Epoch number 0
#  Current loss 0.8359977006912231
#
# Epoch number 0
#  Current loss 0.5933904647827148
#
# Epoch number 0
#  Current loss 0.8096738457679749
#
# Epoch number 0
#  Current loss 0.7264463305473328
#
# Epoch number 0
#  Current loss 0.643404483795166
#
# Epoch number 0
#  Current loss 0.5903736352920532
#
# Epoch number 0
#  Current loss 0.6185529232025146
#
# Epoch number 0
#  Current loss 0.559583306312561
#
# Epoch number 0
#  Current loss 0.4185447096824646
#
# Epoch number 0
#  Current loss 0.532928466796875
#
# Epoch number 0
#  Current loss 0.47227656841278076
#
# Epoch number 0
#  Current loss 0.6647849082946777
#
# Epoch number 0
#  Current loss 0.6694247722625732
#
# Epoch number 0
#  Current loss 0.8313249349594116
#
# Epoch number 0
#  Current loss 0.7042571306228638
#
# Epoch number 0
#  Current loss 0.5732470750808716
#
# Epoch number 0
#  Current loss 0.8469423055648804
#
# Epoch number 0
#  Current loss 0.5979340076446533
#
# Epoch number 0
#  Current loss 0.5580671429634094
#
# Epoch number 0
#  Current loss 0.7243952751159668
#
# Epoch number 0
#  Current loss 0.5738624334335327
#
# Epoch number 0
#  Current loss 0.624819278717041
#
# Epoch number 0
#  Current loss 0.6374988555908203
#
# Epoch number 0
#  Current loss 0.5487422347068787
#
# Epoch number 0
#  Current loss 0.6654888391494751
#
# Epoch number 0
#  Current loss 0.6624064445495605
#
# Epoch number 0
#  Current loss 0.5913053750991821
#
# Epoch number 0
#  Current loss 0.6992716789245605
#
# Epoch number 0
#  Current loss 0.5679455995559692
#
# Epoch number 0
#  Current loss 0.6304417848587036
#
# Epoch number 0
#  Current loss 0.6918429136276245
#
# Epoch number 0
#  Current loss 0.612764298915863
#
# Epoch number 0
#  Current loss 0.7886539697647095
#
# Epoch number 0
#  Current loss 0.644271969795227
#
# Epoch number 0
#  Current loss 0.692501425743103
#
# Epoch number 0
#  Current loss 0.6374542713165283
#
# Epoch number 0
#  Current loss 0.6481926441192627
#
# Epoch number 0
#  Current loss 0.8205256462097168
#
# Epoch number 0
#  Current loss 0.5743125677108765
#
# Epoch number 0
#  Current loss 0.9455674290657043
#
# Epoch number 0
#  Current loss 0.6079198122024536
#
# Epoch number 0
#  Current loss 0.5651237964630127
#
# Epoch number 0
#  Current loss 0.610644519329071
#
# Epoch number 0
#  Current loss 0.7922989130020142
#
# Epoch number 0
#  Current loss 0.5604283213615417
#
# Epoch number 0
#  Current loss 0.4501059055328369
#
# Epoch number 0
#  Current loss 0.5455026626586914
#
# Epoch number 0
#  Current loss 0.5905393958091736
#
# Epoch number 0
#  Current loss 0.8761076927185059
#
# Epoch number 0
#  Current loss 0.5831098556518555
#
# Epoch number 0
#  Current loss 0.5490533709526062
#
# Epoch number 0
#  Current loss 0.6468331813812256
#
# Epoch number 0
#  Current loss 0.4650546610355377
#
# Epoch number 0
#  Current loss 0.8090171217918396
#
# Epoch number 0
#  Current loss 0.5914582014083862
#
# Epoch number 0
#  Current loss 0.5524668097496033
#
# Epoch number 0
#  Current loss 0.6734423041343689
#
# Epoch number 0
#  Current loss 0.6669737100601196
#
# Epoch number 0
#  Current loss 0.590808629989624
#
# Epoch number 0
#  Current loss 0.5643590688705444
#
# Epoch number 0
#  Current loss 0.5626394748687744
#
# Epoch number 0
#  Current loss 0.68133944272995
#
# Epoch number 0
#  Current loss 0.5950588583946228
#
# Epoch number 0
#  Current loss 0.7294350862503052
#
# Epoch number 0
#  Current loss 0.34581583738327026
#
# Epoch number 0
#  Current loss 0.5307241678237915
#
# Epoch number 0
#  Current loss 0.653099775314331
#
# Epoch number 0
#  Current loss 0.6436624526977539
#
# Epoch number 0
#  Current loss 0.5350875854492188
#
# Epoch number 0
#  Current loss 0.47948652505874634
#
# Epoch number 0
#  Current loss 0.658042848110199
#
# Epoch number 0
#  Current loss 0.6271864175796509
#
# Epoch number 0
#  Current loss 0.6849943399429321
#
# Epoch number 0
#  Current loss 0.42635947465896606
#
# Epoch number 0
#  Current loss 0.430973619222641
#
# Epoch number 0
#  Current loss 0.694353461265564
#
# Epoch number 0
#  Current loss 0.6223756074905396
#
# Epoch number 0
#  Current loss 0.8019577860832214
#
# Epoch number 0
#  Current loss 0.4832390546798706
#
# Epoch number 0
#  Current loss 0.497794508934021
#
# Epoch number 0
#  Current loss 0.4541093111038208
#
# Epoch number 0
#  Current loss 0.5301204919815063
#
# Epoch number 0
#  Current loss 0.6016345620155334
#
# Epoch number 0
#  Current loss 0.6371452808380127
#
# Epoch number 0
#  Current loss 0.6985955238342285
#
# Epoch number 0
#  Current loss 0.6482378840446472
#
# Epoch number 0
#  Current loss 0.6634886264801025
#
# Epoch number 0
#  Current loss 0.5734764337539673
#
# Epoch number 0
#  Current loss 0.6993242502212524
#
# Epoch number 0
#  Current loss 0.6412268877029419
#
# Epoch number 0
#  Current loss 0.5093528628349304
#
# Epoch number 0
#  Current loss 0.6349300742149353
#
# Epoch number 0
#  Current loss 0.5873398780822754
#
# Epoch number 0
#  Current loss 0.6149299740791321
#
# Epoch number 0
#  Current loss 0.6328408718109131
#
# Epoch number 0
#  Current loss 0.5601106882095337
#
# Epoch number 0
#  Current loss 0.5654954314231873
#
# Epoch number 0
#  Current loss 0.5828258991241455
#
# Epoch number 0
#  Current loss 0.6382790803909302
#
# Epoch number 0
#  Current loss 0.4482031464576721
#
# Epoch number 0
#  Current loss 0.699299693107605
#
# Epoch number 0
#  Current loss 0.7460213899612427
#
# Epoch number 0
#  Current loss 0.5705496668815613
#
# Epoch number 0
#  Current loss 0.5821478366851807
#
# Epoch number 0
#  Current loss 0.7163019180297852
#
# Epoch number 0
#  Current loss 0.9192512035369873
#
# Epoch number 0
#  Current loss 0.7007134556770325
#
# Epoch number 0
#  Current loss 0.5280609130859375
#
# Epoch number 0
#  Current loss 0.6624857783317566
#
# Epoch number 0
#  Current loss 0.5120311379432678
#
# Epoch number 0
#  Current loss 0.6773656606674194
#
# Epoch number 0
#  Current loss 0.7012860178947449
#
# Epoch number 0
#  Current loss 0.6132422685623169
#
# Epoch number 0
#  Current loss 0.6732710599899292
#
# Epoch number 0
#  Current loss 0.43496060371398926
#
# Epoch number 0
#  Current loss 0.7758961319923401
#
# Epoch number 0
#  Current loss 0.614417552947998
#
# Epoch number 0
#  Current loss 0.5700695514678955
#
# Epoch number 0
#  Current loss 0.6131506562232971
#
# Epoch number 0
#  Current loss 0.6482694149017334
#
# Epoch number 0
#  Current loss 0.5316663980484009
#
# Epoch number 0
#  Current loss 0.631295919418335
#
# Epoch number 0
#  Current loss 0.7252305746078491
#
# Epoch number 0
#  Current loss 0.6047877073287964
#
# Epoch number 0
#  Current loss 0.6021217107772827
#
# Epoch number 0
#  Current loss 0.4176505208015442
#
# Epoch number 0
#  Current loss 0.5318988561630249
#
# Epoch number 0
#  Current loss 0.5470458269119263
#
# Epoch number 0
#  Current loss 0.6530971527099609
#
# Epoch number 0
#  Current loss 0.6158413887023926
#
# Epoch number 0
#  Current loss 0.6438924074172974
#
# Epoch number 0
#  Current loss 0.6200252771377563
#
# Epoch number 0
#  Current loss 0.48237326741218567
#
# Epoch number 0
#  Current loss 0.38552403450012207
#
# Epoch number 0
#  Current loss 0.3548762798309326
#
# Epoch number 0
#  Current loss 0.6831977367401123
#
# Epoch number 0
#  Current loss 0.5592364072799683
#
# Epoch number 0
#  Current loss 0.6108661890029907
#
# Epoch number 0
#  Current loss 0.5308337211608887
#
# Epoch number 0
#  Current loss 0.5205050110816956
#
# Epoch number 0
#  Current loss 0.6045280694961548
#
# Epoch number 0
#  Current loss 0.5334568023681641
#
# Epoch number 0
#  Current loss 0.5069663524627686
#
# Epoch number 0
#  Current loss 0.7406042218208313
#
# Epoch number 0
#  Current loss 0.6137533783912659
#
# Epoch number 0
#  Current loss 0.5579954385757446
#
# Epoch number 0
#  Current loss 0.6066858768463135
#
# Epoch number 0
#  Current loss 0.6698262691497803
#
# Epoch number 0
#  Current loss 0.5019101500511169
#
# Epoch number 0
#  Current loss 0.4545779228210449
#
# Epoch number 0
#  Current loss 0.5449804663658142
#
# Epoch number 0
#  Current loss 0.4225870370864868
#
# Epoch number 0
#  Current loss 0.6044110655784607
#
# Epoch number 0
#  Current loss 0.7452379465103149
#
# Epoch number 0
#  Current loss 0.7242885828018188
#
# Epoch number 0
#  Current loss 0.5554163455963135
#
# Epoch number 0
#  Current loss 0.47753697633743286
#
# Epoch number 0
#  Current loss 0.8440728187561035
#
# Epoch number 0
#  Current loss 0.6416999101638794
#
# Epoch number 0
#  Current loss 0.5649325251579285
#
# Epoch number 0
#  Current loss 0.600028932094574
#
# Epoch number 0
#  Current loss 0.768739640712738
#
# Epoch number 0
#  Current loss 0.6701563000679016
#
# Epoch number 0
#  Current loss 0.6502875089645386
#
# Epoch number 0
#  Current loss 0.48882412910461426
#
# Epoch number 0
#  Current loss 0.6911840438842773
#
# Epoch number 0
#  Current loss 0.7747073769569397
#
# Epoch number 0
#  Current loss 0.5048943758010864
#
# Epoch number 0
#  Current loss 0.849906861782074
#
# Epoch number 0
#  Current loss 0.6047835350036621
#
# Epoch number 0
#  Current loss 0.5900179147720337
#
# Epoch number 0
#  Current loss 0.5885028839111328
#
# Epoch number 0
#  Current loss 0.5412245988845825
#
# Epoch number 0
#  Current loss 0.4417210817337036
#
# Epoch number 0
#  Current loss 0.581640899181366
#
# Epoch number 0
#  Current loss 0.5063521265983582
#
# Epoch number 0
#  Current loss 0.4278562664985657
#
# Epoch number 0
#  Current loss 0.6158740520477295
#
# Epoch number 0
#  Current loss 0.6566908359527588
#
# Epoch number 0
#  Current loss 0.5160061717033386
#
# Epoch number 0
#  Current loss 0.5480607151985168
#
# Epoch number 0
#  Current loss 0.4010657072067261
#
# Epoch number 0
#  Current loss 0.5504834651947021
#
# Epoch number 0
#  Current loss 0.681248664855957
#
# Epoch number 0
#  Current loss 0.2996404767036438
#
# Epoch number 0
#  Current loss 0.5285731554031372
#
# Epoch number 0
#  Current loss 0.4744427800178528
#
# Epoch number 0
#  Current loss 0.4879249930381775
#
# Epoch number 0
#  Current loss 0.5202275514602661
#
# Epoch number 0
#  Current loss 0.6649877429008484
#
# Epoch number 0
#  Current loss 0.6806042790412903
#
# Epoch number 0
#  Current loss 0.4125361442565918
#
# Epoch number 0
#  Current loss 0.5071911811828613
#
# Epoch number 0
#  Current loss 0.6175899505615234
#
# Epoch number 0
#  Current loss 0.5475515127182007
#
# Epoch number 0
#  Current loss 0.5355546474456787
#
# Epoch number 0
#  Current loss 0.37376919388771057
#
# Epoch number 0
#  Current loss 0.7361240386962891
#
# Epoch number 0
#  Current loss 0.45859813690185547
#
# Epoch number 0
#  Current loss 0.45363134145736694
#
# Epoch number 0
#  Current loss 0.5483289957046509
#
# Epoch number 0
#  Current loss 0.6786913871765137
#
# Epoch number 0
#  Current loss 0.44593507051467896
#
# Epoch number 0
#  Current loss 0.6746991872787476
#
# Epoch number 0
#  Current loss 0.5979999303817749
#
# Epoch number 0
#  Current loss 0.4431503415107727
#
# Epoch number 0
#  Current loss 0.5148875117301941
#
# Epoch number 0
#  Current loss 0.6038626432418823
#
# Epoch number 0
#  Current loss 0.6668077707290649
#
# Epoch number 0
#  Current loss 0.5566886067390442
#
# Epoch number 0
#  Current loss 0.7488101124763489
#
# Epoch number 0
#  Current loss 0.4887691140174866
#
# Epoch number 1
#  Current loss 0.7778476476669312
#
# Epoch number 1
#  Current loss 0.6004420518875122
#
# Epoch number 1
#  Current loss 0.6504955291748047
#
# Epoch number 1
#  Current loss 0.5808701515197754
#
# Epoch number 1
#  Current loss 0.6604647636413574
#
# Epoch number 1
#  Current loss 0.5389521718025208
#
# Epoch number 1
#  Current loss 0.6636111736297607
#
# Epoch number 1
#  Current loss 0.7275447845458984
#
# Epoch number 1
#  Current loss 0.48933279514312744
#
# Epoch number 1
#  Current loss 0.6312203407287598
#
# Epoch number 1
#  Current loss 0.5244884490966797
#
# Epoch number 1
#  Current loss 0.464226633310318
#
# Epoch number 1
#  Current loss 0.7212904691696167
#
# Epoch number 1
#  Current loss 0.690295934677124
#
# Epoch number 1
#  Current loss 0.558733344078064
#
# Epoch number 1
#  Current loss 0.4782469868659973
#
# Epoch number 1
#  Current loss 0.5826056003570557
#
# Epoch number 1
#  Current loss 0.6399438381195068
#
# Epoch number 1
#  Current loss 0.5395951271057129
#
# Epoch number 1
#  Current loss 0.535545825958252
#
# Epoch number 1
#  Current loss 0.44535142183303833
#
# Epoch number 1
#  Current loss 0.6844649314880371
#
# Epoch number 1
#  Current loss 0.6917160749435425
#
# Epoch number 1
#  Current loss 0.7385193109512329
#
# Epoch number 1
#  Current loss 0.6613612174987793
#
# Epoch number 1
#  Current loss 0.5670899152755737
#
# Epoch number 1
#  Current loss 0.5391548871994019
#
# Epoch number 1
#  Current loss 0.5713977217674255
#
# Epoch number 1
#  Current loss 0.5969646573066711
#
# Epoch number 1
#  Current loss 0.5987718105316162
#
# Epoch number 1
#  Current loss 0.5606908798217773
#
# Epoch number 1
#  Current loss 0.5598737597465515
#
# Epoch number 1
#  Current loss 0.45408540964126587
#
# Epoch number 1
#  Current loss 0.47655534744262695
#
# Epoch number 1
#  Current loss 0.47561413049697876
#
# Epoch number 1
#  Current loss 0.6606282591819763
#
# Epoch number 1
#  Current loss 0.4423942565917969
#
# Epoch number 1
#  Current loss 0.4150358736515045
#
# Epoch number 1
#  Current loss 0.5592269897460938
#
# Epoch number 1
#  Current loss 0.4754321575164795
#
# Epoch number 1
#  Current loss 0.5322620272636414
#
# Epoch number 1
#  Current loss 0.4694557785987854
#
# Epoch number 1
#  Current loss 0.5896741151809692
#
# Epoch number 1
#  Current loss 0.5680896639823914
#
# Epoch number 1
#  Current loss 0.5591273307800293
#
# Epoch number 1
#  Current loss 0.8706626892089844
#
# Epoch number 1
#  Current loss 0.33862364292144775
#
# Epoch number 1
#  Current loss 0.6217471361160278
#
# Epoch number 1
#  Current loss 0.6382300853729248
#
# Epoch number 1
#  Current loss 0.5216614007949829
#
# Epoch number 1
#  Current loss 0.45942774415016174
#
# Epoch number 1
#  Current loss 0.44256213307380676
#
# Epoch number 1
#  Current loss 0.5240191221237183
#
# Epoch number 1
#  Current loss 0.5198105573654175
#
# Epoch number 1
#  Current loss 0.5329055190086365
#
# Epoch number 1
#  Current loss 0.4787442088127136
#
# Epoch number 1
#  Current loss 0.6323725581169128
#
# Epoch number 1
#  Current loss 0.6157331466674805
#
# Epoch number 1
#  Current loss 0.5728726387023926
#
# Epoch number 1
#  Current loss 0.47002553939819336
#
# Epoch number 1
#  Current loss 0.6112359762191772
#
# Epoch number 1
#  Current loss 0.4918198585510254
#
# Epoch number 1
#  Current loss 0.48382699489593506
#
# Epoch number 1
#  Current loss 0.6121513247489929
#
# Epoch number 1
#  Current loss 0.7287800908088684
#
# Epoch number 1
#  Current loss 0.8583905696868896
#
# Epoch number 1
#  Current loss 0.3239405155181885
#
# Epoch number 1
#  Current loss 0.576659083366394
#
# Epoch number 1
#  Current loss 0.5603796243667603
#
# Epoch number 1
#  Current loss 0.8942266702651978
#
# Epoch number 1
#  Current loss 0.6102514266967773
#
# Epoch number 1
#  Current loss 0.5979820489883423
#
# Epoch number 1
#  Current loss 0.6513614654541016
#
# Epoch number 1
#  Current loss 0.570844292640686
#
# Epoch number 1
#  Current loss 0.5172845721244812
#
# Epoch number 1
#  Current loss 0.3424690365791321
#
# Epoch number 1
#  Current loss 0.5428360104560852
#
# Epoch number 1
#  Current loss 0.7850348949432373
#
# Epoch number 1
#  Current loss 0.48872628808021545
#
# Epoch number 1
#  Current loss 0.6336108446121216
#
# Epoch number 1
#  Current loss 0.5921962261199951
#
# Epoch number 1
#  Current loss 0.425509512424469
#
# Epoch number 1
#  Current loss 0.5416807532310486
#
# Epoch number 1
#  Current loss 0.4965936541557312
#
# Epoch number 1
#  Current loss 0.6418411731719971
#
# Epoch number 1
#  Current loss 0.5853474140167236
#
# Epoch number 1
#  Current loss 0.7706068754196167
#
# Epoch number 1
#  Current loss 0.4709851145744324
#
# Epoch number 1
#  Current loss 0.5497007369995117
#
# Epoch number 1
#  Current loss 0.45897412300109863
#
# Epoch number 1
#  Current loss 0.6453647613525391
#
# Epoch number 1
#  Current loss 0.8226858377456665
#
# Epoch number 1
#  Current loss 0.5386146306991577
#
# Epoch number 1
#  Current loss 0.6212328672409058
#
# Epoch number 1
#  Current loss 0.5070600509643555
#
# Epoch number 1
#  Current loss 0.4556422233581543
#
# Epoch number 1
#  Current loss 0.799962043762207
#
# Epoch number 1
#  Current loss 0.5732369422912598
#
# Epoch number 1
#  Current loss 0.5095103979110718
#
# Epoch number 1
#  Current loss 0.6055973172187805
#
# Epoch number 1
#  Current loss 0.5591679811477661
#
# Epoch number 1
#  Current loss 0.6326532363891602
#
# Epoch number 1
#  Current loss 0.45578545331954956
#
# Epoch number 1
#  Current loss 0.6392899751663208
#
# Epoch number 1
#  Current loss 0.7162024974822998
#
# Epoch number 1
#  Current loss 0.4047513008117676
#
# Epoch number 1
#  Current loss 0.5185914039611816
#
# Epoch number 1
#  Current loss 0.49058884382247925
#
# Epoch number 1
#  Current loss 0.4220430254936218
#
# Epoch number 1
#  Current loss 0.5549551844596863
#
# Epoch number 1
#  Current loss 0.5281533002853394
#
# Epoch number 1
#  Current loss 0.5383492708206177
#
# Epoch number 1
#  Current loss 0.8022725582122803
#
# Epoch number 1
#  Current loss 0.5696462988853455
#
# Epoch number 1
#  Current loss 0.399588018655777
#
# Epoch number 1
#  Current loss 0.5260393619537354
#
# Epoch number 1
#  Current loss 0.5507216453552246
#
# Epoch number 1
#  Current loss 0.8124668002128601
#
# Epoch number 1
#  Current loss 0.5188615322113037
#
# Epoch number 1
#  Current loss 0.5168424844741821
#
# Epoch number 1
#  Current loss 0.504713773727417
#
# Epoch number 1
#  Current loss 0.4770592451095581
#
# Epoch number 1
#  Current loss 0.49307340383529663
#
# Epoch number 1
#  Current loss 0.5750806331634521
#
# Epoch number 1
#  Current loss 0.6254732012748718
#
# Epoch number 1
#  Current loss 0.6449911594390869
#
# Epoch number 1
#  Current loss 0.5385429859161377
#
# Epoch number 1
#  Current loss 0.6011917591094971
#
# Epoch number 1
#  Current loss 0.4757213592529297
#
# Epoch number 1
#  Current loss 0.4025232493877411
#
# Epoch number 1
#  Current loss 0.6519235372543335
#
# Epoch number 1
#  Current loss 0.5511021018028259
#
# Epoch number 1
#  Current loss 0.46043455600738525
#
# Epoch number 1
#  Current loss 0.5632089376449585
#
# Epoch number 1
#  Current loss 0.7044391632080078
#
# Epoch number 1
#  Current loss 0.5262061357498169
#
# Epoch number 1
#  Current loss 0.4999677240848541
#
# Epoch number 1
#  Current loss 0.6513252258300781
#
# Epoch number 1
#  Current loss 0.4600926637649536
#
# Epoch number 1
#  Current loss 0.5130538940429688
#
# Epoch number 1
#  Current loss 0.4301663637161255
#
# Epoch number 1
#  Current loss 0.5548328757286072
#
# Epoch number 1
#  Current loss 0.44104138016700745
#
# Epoch number 1
#  Current loss 0.5827406644821167
#
# Epoch number 1
#  Current loss 0.43640315532684326
#
# Epoch number 1
#  Current loss 0.592095136642456
#
# Epoch number 1
#  Current loss 0.6039552092552185
#
# Epoch number 1
#  Current loss 0.5374294519424438
#
# Epoch number 1
#  Current loss 0.4185038208961487
#
# Epoch number 1
#  Current loss 0.4346252381801605
#
# Epoch number 1
#  Current loss 0.40655869245529175
#
# Epoch number 1
#  Current loss 0.40907639265060425
#
# Epoch number 1
#  Current loss 0.5635079145431519
#
# Epoch number 1
#  Current loss 0.6215252876281738
#
# Epoch number 1
#  Current loss 0.6276641488075256
#
# Epoch number 1
#  Current loss 0.6199774146080017
#
# Epoch number 1
#  Current loss 0.9555472135543823
#
# Epoch number 1
#  Current loss 0.4823026657104492
#
# Epoch number 1
#  Current loss 0.7502695322036743
#
# Epoch number 1
#  Current loss 0.6216158866882324
#
# Epoch number 1
#  Current loss 0.5188559293746948
#
# Epoch number 1
#  Current loss 0.39482688903808594
#
# Epoch number 1
#  Current loss 0.5331397652626038
#
# Epoch number 1
#  Current loss 0.4290442168712616
#
# Epoch number 1
#  Current loss 0.6758866906166077
#
# Epoch number 1
#  Current loss 0.6489547491073608
#
# Epoch number 1
#  Current loss 0.43708378076553345
#
# Epoch number 1
#  Current loss 0.5690258741378784
#
# Epoch number 1
#  Current loss 0.3656810522079468
#
# Epoch number 1
#  Current loss 0.5607785582542419
#
# Epoch number 1
#  Current loss 0.5342336297035217
#
# Epoch number 1
#  Current loss 0.6315711736679077
#
# Epoch number 1
#  Current loss 0.5393844842910767
#
# Epoch number 1
#  Current loss 0.5440682172775269
#
# Epoch number 1
#  Current loss 0.6242254972457886
#
# Epoch number 1
#  Current loss 0.42916542291641235
#
# Epoch number 1
#  Current loss 0.34900790452957153
#
# Epoch number 1
#  Current loss 0.539592444896698
#
# Epoch number 1
#  Current loss 0.41435927152633667
#
# Epoch number 1
#  Current loss 0.5310094356536865
#
# Epoch number 1
#  Current loss 0.6677327156066895
#
# Epoch number 1
#  Current loss 0.5921461582183838
#
# Epoch number 1
#  Current loss 0.6038610935211182
#
# Epoch number 1
#  Current loss 0.6185468435287476
#
# Epoch number 1
#  Current loss 0.36816927790641785
#
# Epoch number 1
#  Current loss 0.4023119807243347
#
# Epoch number 1
#  Current loss 0.5095967650413513
#
# Epoch number 1
#  Current loss 0.5244084000587463
#
# Epoch number 1
#  Current loss 0.44247496128082275
#
# Epoch number 1
#  Current loss 0.6014868021011353
#
# Epoch number 1
#  Current loss 0.6306884288787842
#
# Epoch number 1
#  Current loss 0.47409576177597046
#
# Epoch number 1
#  Current loss 0.5805974006652832
#
# Epoch number 1
#  Current loss 0.7387287616729736
#
# Epoch number 1
#  Current loss 0.5287313461303711
#
# Epoch number 1
#  Current loss 0.5762894153594971
#
# Epoch number 1
#  Current loss 0.605385422706604
#
# Epoch number 1
#  Current loss 0.3803465962409973
#
# Epoch number 1
#  Current loss 0.5225694179534912
#
# Epoch number 1
#  Current loss 0.47694650292396545
#
# Epoch number 1
#  Current loss 0.601620078086853
#
# Epoch number 1
#  Current loss 0.4405480623245239
#
# Epoch number 1
#  Current loss 0.42750436067581177
#
# Epoch number 1
#  Current loss 0.47431039810180664
#
# Epoch number 1
#  Current loss 0.5115121006965637
#
# Epoch number 1
#  Current loss 0.6029850244522095
#
# Epoch number 1
#  Current loss 0.5513303279876709
#
# Epoch number 1
#  Current loss 0.4583353102207184
#
# Epoch number 1
#  Current loss 0.527449369430542
#
# Epoch number 1
#  Current loss 0.7237975597381592
#
# Epoch number 1
#  Current loss 0.48595190048217773
#
# Epoch number 1
#  Current loss 0.4959661662578583
#
# Epoch number 1
#  Current loss 0.5223128795623779
#
# Epoch number 1
#  Current loss 0.5674070119857788
#
# Epoch number 1
#  Current loss 0.5402354598045349
#
# Epoch number 1
#  Current loss 0.615525484085083
#
# Epoch number 1
#  Current loss 0.47585195302963257
#
# Epoch number 1
#  Current loss 0.5070314407348633
#
# Epoch number 1
#  Current loss 0.4057667851448059
#
# Epoch number 1
#  Current loss 0.48445942997932434
#
# Epoch number 1
#  Current loss 0.5042692422866821
#
# Epoch number 1
#  Current loss 0.49195975065231323
#
# Epoch number 1
#  Current loss 0.5445243716239929
#
# Epoch number 1
#  Current loss 0.5710223317146301
#
# Epoch number 1
#  Current loss 0.3706435561180115
#
# Epoch number 1
#  Current loss 0.5424904823303223
#
# Epoch number 1
#  Current loss 0.4311302900314331
#
# Epoch number 1
#  Current loss 0.5879110097885132
#
# Epoch number 1
#  Current loss 0.5705497860908508
#
# Epoch number 1
#  Current loss 0.6411052942276001
#
# Epoch number 1
#  Current loss 0.35741400718688965
#
# Epoch number 1
#  Current loss 0.5869841575622559
#
# Epoch number 1
#  Current loss 0.691332221031189
#
# Epoch number 1
#  Current loss 0.6492525339126587
#
# Epoch number 1
#  Current loss 0.4626981019973755
#
# Epoch number 1
#  Current loss 0.5075771808624268
#
# Epoch number 1
#  Current loss 0.36043471097946167
#
# Epoch number 1
#  Current loss 0.41825050115585327
#
# Epoch number 1
#  Current loss 0.5814250707626343
#
# Epoch number 1
#  Current loss 0.6051453948020935
#
# Epoch number 1
#  Current loss 0.5922242403030396
#
# Epoch number 1
#  Current loss 0.6024723052978516
#
# Epoch number 1
#  Current loss 0.46266984939575195
#
# Epoch number 1
#  Current loss 0.4523325562477112
#
# Epoch number 1
#  Current loss 0.4700932502746582
#
# Epoch number 1
#  Current loss 0.45199528336524963
#
# Epoch number 1
#  Current loss 0.7193907499313354
#
# Epoch number 1
#  Current loss 0.5003980398178101
#
# Epoch number 1
#  Current loss 0.3952290415763855
#
# Epoch number 1
#  Current loss 0.3680958151817322
#
# Epoch number 1
#  Current loss 0.530579149723053
#
# Epoch number 1
#  Current loss 0.6001777052879333
#
# Epoch number 1
#  Current loss 0.3062359690666199
#
# Epoch number 1
#  Current loss 0.5879027843475342
#
# Epoch number 1
#  Current loss 0.6201586127281189
#
# Epoch number 1
#  Current loss 0.424789696931839
#
# Epoch number 1
#  Current loss 0.4837982654571533
#
# Epoch number 1
#  Current loss 0.4912305474281311
#
# Epoch number 1
#  Current loss 0.5381415486335754
#
# Epoch number 1
#  Current loss 0.6788969039916992
#
# Epoch number 1
#  Current loss 0.6679065227508545
#
# Epoch number 1
#  Current loss 0.5098071098327637
#
# Epoch number 1
#  Current loss 0.6742215156555176
#
# Epoch number 1
#  Current loss 0.5445403456687927
#
# Epoch number 1
#  Current loss 0.5160611271858215
#
# Epoch number 1
#  Current loss 0.4194502830505371
#
# Epoch number 1
#  Current loss 0.6941424012184143
#
# Epoch number 1
#  Current loss 0.6969209909439087
#
# Epoch number 1
#  Current loss 0.41400906443595886
#
# Epoch number 1
#  Current loss 0.4896555244922638
#
# Epoch number 1
#  Current loss 0.44774383306503296
#
# Epoch number 1
#  Current loss 0.5299853682518005
#
# Epoch number 1
#  Current loss 0.45755648612976074
#
# Epoch number 1
#  Current loss 0.5147272348403931
#
# Epoch number 1
#  Current loss 0.4449649751186371
#
# Epoch number 1
#  Current loss 0.384763240814209
#
# Epoch number 1
#  Current loss 0.5692197680473328
#
# Epoch number 1
#  Current loss 0.5681475400924683
#
# Epoch number 1
#  Current loss 0.5263270735740662
#
# Epoch number 1
#  Current loss 0.7373789548873901
#
# Epoch number 1
#  Current loss 0.5515641570091248
#
# Epoch number 1
#  Current loss 0.39724403619766235
#
# Epoch number 1
#  Current loss 0.5309399366378784
#
# Epoch number 1
#  Current loss 0.5109323263168335
#
# Epoch number 1
#  Current loss 0.48342597484588623
#
# Epoch number 1
#  Current loss 0.481708824634552
#
# Epoch number 1
#  Current loss 0.49829933047294617
#
# Epoch number 1
#  Current loss 0.612351655960083
#
# Epoch number 1
#  Current loss 0.35387593507766724
#
# Epoch number 1
#  Current loss 0.4344746470451355
#
# Epoch number 1
#  Current loss 0.580662190914154
#
# Epoch number 1
#  Current loss 0.8134520053863525
#
# Epoch number 1
#  Current loss 0.6456069946289062
#
# Epoch number 1
#  Current loss 0.4579639434814453
#
# Epoch number 1
#  Current loss 0.5036278963088989
#
# Epoch number 1
#  Current loss 0.7379254102706909
#
# Epoch number 1
#  Current loss 0.4345172047615051
#
# Epoch number 1
#  Current loss 0.5331669449806213
#
# Epoch number 1
#  Current loss 0.4868786633014679
#
# Epoch number 1
#  Current loss 0.587576150894165
#
# Epoch number 1
#  Current loss 0.5377861857414246
#
# Epoch number 1
#  Current loss 0.5192158222198486
#
# Epoch number 1
#  Current loss 0.5125401616096497
#
# Epoch number 1
#  Current loss 0.5509795546531677
#
# Epoch number 1
#  Current loss 0.4776068329811096
#
# Epoch number 1
#  Current loss 0.5728768110275269
#
# Epoch number 1
# ...
#
# Epoch number 29
#  Current loss 0.11875692754983902
#
# Epoch number 29
#  Current loss 0.10311798751354218
#
# Epoch number 29
#  Current loss 0.30941954255104065
#
# Epoch number 29
#  Current loss 0.26733794808387756
#
# Epoch number 29
#  Current loss 0.1575106978416443
#
# Epoch number 29
#  Current loss 0.30406472086906433
#
# Epoch number 29
#  Current loss 0.14657138288021088
#
# Epoch number 29
#  Current loss 0.15937688946723938
#
# Epoch number 29
#  Current loss 0.18853938579559326
#
# Epoch number 29
#  Current loss 0.2351996898651123
#
# Epoch number 29
#  Current loss 0.344668984413147
#
# Epoch number 29
#  Current loss 0.15695422887802124
#
# Epoch number 29
#  Current loss 0.20074410736560822
#
# Epoch number 29
#  Current loss 0.18020880222320557
#
# Epoch number 29
#  Current loss 0.2294493317604065
#
# Epoch number 29
#  Current loss 0.16232463717460632
#
# Epoch number 29
#  Current loss 0.2515545189380646
#
# Epoch number 29
#  Current loss 0.11082085967063904
#
# Epoch number 29
#  Current loss 0.14552485942840576
#
# Epoch number 29
#  Current loss 0.24272960424423218
#
# Epoch number 29
#  Current loss 0.24229496717453003
#
# Epoch number 29
#  Current loss 0.06548579037189484
#
# Epoch number 29
#  Current loss 0.19072017073631287
#
# Epoch number 29
#  Current loss 0.2129504680633545
#
# Epoch number 29
#  Current loss 0.08891208469867706
#
# Epoch number 29
#  Current loss 0.11182990670204163
#
# Epoch number 29
#  Current loss 0.11945118010044098
#
# Epoch number 29
#  Current loss 0.07205809652805328
#
# Epoch number 29
#  Current loss 0.09267386794090271
#
# Epoch number 29
#  Current loss 0.25858837366104126
#
# Epoch number 29
#  Current loss 0.13461066782474518
#
# Epoch number 29
#  Current loss 0.11477136611938477
#
# Epoch number 29
#  Current loss 0.25146326422691345
#
# Epoch number 29
#  Current loss 0.2883530259132385
#
# Epoch number 29
#  Current loss 0.21875759959220886
#
# Epoch number 29
#  Current loss 0.1194981262087822
#
# Epoch number 29
#  Current loss 0.10150375962257385
#
# Epoch number 29
#  Current loss 0.2094113528728485
#
# Epoch number 29
#  Current loss 0.10222268104553223
#
# Epoch number 29
#  Current loss 0.17041505873203278
#
# Epoch number 29
#  Current loss 0.2027868777513504
#
# Epoch number 29
#  Current loss 0.09412001073360443
#
# Epoch number 29
#  Current loss 0.08671797066926956
#
# Epoch number 29
#  Current loss 0.16843393445014954
#
# Epoch number 29
#  Current loss 0.18582069873809814
#
# Epoch number 29
#  Current loss 0.08783469349145889
#
# Epoch number 29
#  Current loss 0.2139817178249359
#
# Epoch number 29
#  Current loss 0.11782762408256531
#
# Epoch number 29
#  Current loss 0.29877960681915283
#
# Epoch number 29
#  Current loss 0.10772594064474106
#
# Epoch number 29
#  Current loss 0.17409804463386536
#
# Epoch number 29
#  Current loss 0.10515103489160538
#
# Epoch number 29
#  Current loss 0.2205590009689331
#
# Epoch number 29
#  Current loss 0.15722957253456116
#
# Epoch number 29
#  Current loss 0.17954497039318085
#
# Epoch number 29
#  Current loss 0.13195301592350006
#
# Epoch number 29
#  Current loss 0.12619724869728088
#
# Epoch number 29
#  Current loss 0.13604670763015747
#
# Epoch number 29
#  Current loss 0.07850103080272675
#
# Epoch number 29
#  Current loss 0.2450716495513916
#
# Epoch number 29
#  Current loss 0.11552758514881134
#
# Epoch number 29
#  Current loss 0.11081849038600922
#
# Epoch number 29
#  Current loss 0.15391135215759277
#
# Epoch number 29
#  Current loss 0.2733978033065796
#
# Epoch number 29
#  Current loss 0.11894600093364716
#
# Epoch number 29
#  Current loss 0.3188527822494507
#
# Epoch number 29
#  Current loss 0.05076989531517029
#
# Epoch number 29
#  Current loss 0.16086722910404205
#
# Epoch number 29
#  Current loss 0.16134275496006012
#
# Epoch number 29
#  Current loss 0.17421701550483704
#
# Epoch number 29
#  Current loss 0.21879172325134277
#
# Epoch number 29
#  Current loss 0.28023195266723633
#
# Epoch number 29
#  Current loss 0.32711347937583923
#
# Epoch number 29
#  Current loss 0.32053327560424805
#
# Epoch number 29
#  Current loss 0.14199425280094147
#
# Epoch number 29
#  Current loss 0.11010968685150146
#
# Epoch number 29
#  Current loss 0.28343987464904785
#
# Epoch number 29
#  Current loss 0.29343050718307495
#
# Epoch number 29
#  Current loss 0.2588091194629669
#
# Epoch number 29
#  Current loss 0.13009758293628693
#
# Epoch number 29
#  Current loss 0.14531433582305908
#
# Epoch number 29
#  Current loss 0.23907090723514557
#
# Epoch number 29
#  Current loss 0.22140240669250488
#
# Epoch number 29
#  Current loss 0.17493830621242523
#
# Epoch number 29
#  Current loss 0.1431836187839508
#
# Epoch number 29
#  Current loss 0.05608358979225159
#
# Epoch number 29
#  Current loss 0.16045814752578735
#
# Epoch number 29
#  Current loss 0.16696321964263916
#
# Epoch number 29
#  Current loss 0.2431614100933075
#
# Epoch number 29
#  Current loss 0.15554381906986237
#
# Epoch number 29
#  Current loss 0.17505712807178497
#
# Epoch number 29
#  Current loss 0.2651587426662445
#
# Epoch number 29
#  Current loss 0.11393480002880096
#
# Epoch number 29
#  Current loss 0.1799601912498474
#
# Epoch number 29
#  Current loss 0.12298909574747086
#
# Epoch number 29
#  Current loss 0.06341693550348282
#
# Epoch number 29
#  Current loss 0.07993502914905548
#
# Epoch number 29
#  Current loss 0.21698537468910217
#
# Epoch number 29
#  Current loss 0.1683366894721985
#
# Epoch number 29
#  Current loss 0.09583151340484619
#
# Epoch number 29
#  Current loss 0.06320539116859436
#
# Epoch number 29
#  Current loss 0.19523382186889648
#
# Epoch number 29
#  Current loss 0.18134135007858276
#
# Epoch number 29
#  Current loss 0.07647819817066193
#
# Epoch number 29
#  Current loss 0.1877312958240509
#
# Epoch number 29
#  Current loss 0.11462587118148804
#
# Epoch number 29
#  Current loss 0.05389415845274925
#
# Epoch number 29
#  Current loss 0.2549422085285187
#
# Epoch number 29
#  Current loss 0.16641944646835327
#
# Epoch number 29
#  Current loss 0.1942843794822693
#
# Epoch number 29
#  Current loss 0.16730983555316925
#
# Epoch number 29
#  Current loss 0.12277840077877045
#
# Epoch number 29
#  Current loss 0.10598641633987427
#
# Epoch number 29
#  Current loss 0.3232342600822449
#
# Epoch number 29
#  Current loss 0.3747788667678833
#
# Epoch number 29
#  Current loss 0.21466481685638428
#
# Epoch number 29
#  Current loss 0.23170462250709534
#
# Epoch number 29
#  Current loss 0.08550116419792175
#
# Epoch number 29
#  Current loss 0.2862240672111511
#
# Epoch number 29
#  Current loss 0.15723514556884766
#
# Epoch number 29
#  Current loss 0.10440871119499207
#
# Epoch number 29
#  Current loss 0.1868993043899536
#
# Epoch number 29
#  Current loss 0.11300525069236755
#
# Epoch number 29
#  Current loss 0.22994542121887207
#
# Epoch number 29
#  Current loss 0.1671934276819229
#
# Epoch number 29
#  Current loss 0.07289576530456543
#
# Epoch number 29
#  Current loss 0.25809186697006226
#
# Epoch number 29
#  Current loss 0.243510901927948
#
# Epoch number 29
#  Current loss 0.10829249024391174
#
# Epoch number 29
#  Current loss 0.15033723413944244
#
# Epoch number 29
#  Current loss 0.07833753526210785
#
# Epoch number 29
#  Current loss 0.1856975257396698
#
# Epoch number 29
#  Current loss 0.15698516368865967
#
# Epoch number 29
#  Current loss 0.1251833289861679
#
# Epoch number 29
#  Current loss 0.2628534734249115
#
# Epoch number 29
#  Current loss 0.23223893344402313
#
# Epoch number 29
#  Current loss 0.11327394843101501
#
# Epoch number 29
#  Current loss 0.19466939568519592
#
# Epoch number 29
#  Current loss 0.1741643100976944
#
# Epoch number 29
#  Current loss 0.13785946369171143
#
# Epoch number 29
#  Current loss 0.2260400801897049
#
# Epoch number 29
#  Current loss 0.22124242782592773
#
# Epoch number 29
#  Current loss 0.1439635455608368
#
# Epoch number 29
#  Current loss 0.22946476936340332
#
# Epoch number 29
#  Current loss 0.17626427114009857
#
# Epoch number 29
#  Current loss 0.15355923771858215
#
# Epoch number 29
#  Current loss 0.2004484087228775
#
# Epoch number 29
#  Current loss 0.2980039119720459
#
# Epoch number 29
#  Current loss 0.126285120844841
#
# Epoch number 29
#  Current loss 0.12876957654953003
#
# Epoch number 29
#  Current loss 0.05525487661361694
#
# Epoch number 29
#  Current loss 0.09784296154975891
#
# Epoch number 29
#  Current loss 0.10861630737781525
#
# Epoch number 29
#  Current loss 0.13547611236572266
#
# Epoch number 29
#  Current loss 0.18441426753997803
#
# Epoch number 29
#  Current loss 0.09238061308860779
#
# Epoch number 29
#  Current loss 0.09439297765493393
#
# Epoch number 29
#  Current loss 0.11014407873153687
#
# Epoch number 29
#  Current loss 0.24600769579410553
#
# Epoch number 29
#  Current loss 0.14320141077041626
#
# Epoch number 29
#  Current loss 0.18943628668785095
#
# Epoch number 29
#  Current loss 0.251688688993454
#
# Epoch number 29
#  Current loss 0.09808310121297836
#
# Epoch number 29
#  Current loss 0.15575753152370453
#
# Epoch number 29
#  Current loss 0.15565329790115356
#
# Epoch number 29
#  Current loss 0.13040798902511597
#
# Epoch number 29
#  Current loss 0.209269180893898
#
# Epoch number 29
#  Current loss 0.18508833646774292
#
# Epoch number 29
#  Current loss 0.12422937154769897
#
# Epoch number 29
#  Current loss 0.2059434950351715
#
# Epoch number 29
#  Current loss 0.21989694237709045
#
# Epoch number 29
#  Current loss 0.0863037109375
#
# Epoch number 29
#  Current loss 0.15446022152900696
#
# Epoch number 29
#  Current loss 0.053471390157938004
#
# Epoch number 29
#  Current loss 0.16730564832687378
#
# Epoch number 29
#  Current loss 0.21626624464988708
#
# Epoch number 29
#  Current loss 0.19109509885311127
#
# Epoch number 29
#  Current loss 0.18469713628292084
#
# Epoch number 29
#  Current loss 0.2961961328983307
#
# Epoch number 29
#  Current loss 0.2217368334531784
#
# Epoch number 29
#  Current loss 0.07354982197284698
#
# Epoch number 29
#  Current loss 0.07805705070495605
#
# Epoch number 29
#  Current loss 0.07692974805831909
#
# Epoch number 29
#  Current loss 0.20157502591609955
#
# Epoch number 29
#  Current loss 0.2263040542602539
#
# Epoch number 29
#  Current loss 0.051767732948064804
#
# Epoch number 29
#  Current loss 0.23118767142295837
#
# Epoch number 29
#  Current loss 0.05804114043712616
#
# Epoch number 29
#  Current loss 0.07636978477239609
#
# Epoch number 29
#  Current loss 0.12338618189096451
#
# Epoch number 29
#  Current loss 0.3634932041168213
#
# Epoch number 29
#  Current loss 0.09439997375011444
#
# Epoch number 29
#  Current loss 0.13548091053962708
#
# Epoch number 29
#  Current loss 0.26899099349975586
#
# Epoch number 29
#  Current loss 0.2651756703853607
#
# Epoch number 29
#  Current loss 0.1085943877696991
#
# Epoch number 29
#  Current loss 0.24059176445007324
#
# Epoch number 29
#  Current loss 0.15066321194171906
#
# Epoch number 29
#  Current loss 0.16007637977600098
#
# Epoch number 29
#  Current loss 0.12637363374233246
#
# Epoch number 29
#  Current loss 0.12443864345550537
#
# Epoch number 29
#  Current loss 0.09229729324579239
#
# Epoch number 29
#  Current loss 0.07933572679758072
#
# Epoch number 29
#  Current loss 0.20251426100730896
#
# Epoch number 29
#  Current loss 0.14377498626708984
#
# Epoch number 29
#  Current loss 0.29930028319358826
#
# Epoch number 29
#  Current loss 0.2386734038591385
#
# Epoch number 29
#  Current loss 0.15480178594589233
#
# Epoch number 29
#  Current loss 0.12690749764442444
#
# Epoch number 29
#  Current loss 0.18840672075748444
#
# Epoch number 29
#  Current loss 0.30453529953956604
#
# Epoch number 29
#  Current loss 0.06918522715568542
#
# Epoch number 29
#  Current loss 0.26754230260849
#
# Epoch number 29
#  Current loss 0.20992527902126312
#
# Epoch number 29
#  Current loss 0.1700596809387207
#
# Epoch number 29
#  Current loss 0.15148445963859558
#
# Epoch number 29
#  Current loss 0.1472099870443344
#
# Epoch number 29
#  Current loss 0.30542701482772827
#
# Epoch number 29
#  Current loss 0.13719987869262695
#
# Epoch number 29
#  Current loss 0.19323857128620148
#
# Epoch number 29
#  Current loss 0.15094999969005585
#
# Epoch number 29
#  Current loss 0.1629379689693451
#
# Epoch number 29
#  Current loss 0.1790681630373001
#
# Epoch number 29
#  Current loss 0.0897611528635025
#
# Epoch number 29
#  Current loss 0.14391390979290009
#
# Epoch number 29
#  Current loss 0.2364843487739563
#
# Epoch number 29
#  Current loss 0.1946386843919754
#
# Epoch number 29
#  Current loss 0.08985500782728195
#
# Epoch number 29
#  Current loss 0.1275649517774582
#
# Epoch number 29
#  Current loss 0.16204248368740082
#
# Epoch number 29
#  Current loss 0.18648475408554077
#
# Epoch number 29
#  Current loss 0.07721266150474548
#
# Epoch number 29
#  Current loss 0.10257105529308319
#
# Epoch number 29
#  Current loss 0.1421685516834259
#
# Epoch number 29
#  Current loss 0.13050062954425812
#
# Epoch number 29
#  Current loss 0.136826753616333
#
# Epoch number 29
#  Current loss 0.283464252948761
#
# Epoch number 29
#  Current loss 0.11125317215919495
#
# Epoch number 29
#  Current loss 0.11935661733150482
#
# Epoch number 29
#  Current loss 0.08009587973356247
#
# Epoch number 29
#  Current loss 0.0780368447303772
#
# Epoch number 29
#  Current loss 0.14680129289627075
#
# Epoch number 29
#  Current loss 0.1996702253818512
#
# Epoch number 29
#  Current loss 0.1860671043395996
#
# Epoch number 29
#  Current loss 0.1980748176574707
#
# Epoch number 29
#  Current loss 0.08525808155536652
#
# Epoch number 29
#  Current loss 0.18884000182151794
#
# Epoch number 29
#  Current loss 0.2279036045074463
#
# Epoch number 29
#  Current loss 0.22365213930606842
#
# Epoch number 29
#  Current loss 0.05663148686289787
#
# Epoch number 29
#  Current loss 0.2198331356048584
#
# Epoch number 29
#  Current loss 0.13360553979873657
#
# Epoch number 29
#  Current loss 0.18617062270641327
#
# Epoch number 29
#  Current loss 0.20686320960521698
#
# Epoch number 29
#  Current loss 0.18308532238006592
#
# Epoch number 29
#  Current loss 0.11745841801166534
#
# Epoch number 29
#  Current loss 0.12500567734241486
#
# Epoch number 29
#  Current loss 0.07603412121534348
#
# Epoch number 29
#  Current loss 0.1388355940580368
#
# Epoch number 29
#  Current loss 0.25902682542800903
#
# Epoch number 29
#  Current loss 0.22418265044689178
#
# Epoch number 29
#  Current loss 0.09800176322460175
#
# Epoch number 29
#  Current loss 0.33807986974716187
#
# Epoch number 29
#  Current loss 0.1769014298915863
#
# Epoch number 29
#  Current loss 0.10620009899139404
#
# Epoch number 29
#  Current loss 0.1716306507587433
#
# Epoch number 29
#  Current loss 0.1457221955060959
#
# Epoch number 29
#  Current loss 0.10273440927267075
#
# Epoch number 29
#  Current loss 0.08846499025821686
#
# Epoch number 29
#  Current loss 0.08603256940841675
#
# Epoch number 29
#  Current loss 0.18697589635849
#
# Epoch number 29
#  Current loss 0.05013271048665047
#
# Epoch number 29
#  Current loss 0.18710146844387054
#
# Epoch number 29
#  Current loss 0.12997308373451233
#
# Epoch number 29
#  Current loss 0.11560089886188507
#
# Epoch number 29
#  Current loss 0.045795291662216187
#
# Epoch number 29
#  Current loss 0.1555538773536682
#
# Epoch number 29
#  Current loss 0.3211778700351715
#
# Epoch number 29
#  Current loss 0.1336083710193634
#
# Epoch number 29
#  Current loss 0.09784646332263947
#
# Epoch number 29
#  Current loss 0.2520638108253479
#
# Epoch number 29
#  Current loss 0.04947231709957123
#
# Epoch number 29
#  Current loss 0.07462334632873535
#
# Epoch number 29
#  Current loss 0.07452967017889023
#
# Epoch number 29
#  Current loss 0.07240593433380127
#
# Epoch number 29
#  Current loss 0.14732663333415985
#
# Epoch number 29
#  Current loss 0.054580606520175934
#
# Epoch number 29
#  Current loss 0.191929429769516
#
# Epoch number 29
#  Current loss 0.06865675002336502
#
# Epoch number 29
#  Current loss 0.15177901089191437
#
# Epoch number 29
#  Current loss 0.10865497589111328
#
# Epoch number 29
#  Current loss 0.12276330590248108
#
# Epoch number 29
#  Current loss 0.08136691898107529
#
# Epoch number 29
#  Current loss 0.07828746736049652
#
# Epoch number 29
#  Current loss 0.13909512758255005
#
# Epoch number 29
#  Current loss 0.07807375490665436
#
# Epoch number 29
#  Current loss 0.12139634788036346
#
# Epoch number 29
#  Current loss 0.061970002949237823
#
# Epoch number 29
#  Current loss 0.1615709364414215
#
# Epoch number 29
#  Current loss 0.21318410336971283
#
# Epoch number 29
#  Current loss 0.17368918657302856
#
# Epoch number 29
#  Current loss 0.3723919689655304
#
# Epoch number 29
#  Current loss 0.17584168910980225
#
# Epoch number 29
#  Current loss 0.10268205404281616
#
# Epoch number 29
#  Current loss 0.19769537448883057
#
# Epoch number 29
#  Current loss 0.2150740623474121
#
# Epoch number 29
#  Current loss 0.07536952942609787
#
# Epoch number 29
#  Current loss 0.12382885813713074
#
# Epoch number 29
#  Current loss 0.16288384795188904
#
# Epoch number 29
#  Current loss 0.12843376398086548
#
# Epoch number 29
#  Current loss 0.12868764996528625
#
# Epoch number 29
#  Current loss 0.3271033763885498
#
# Epoch number 29
#  Current loss 0.15600231289863586
#
# Epoch number 29
#  Current loss 0.08180885016918182
#
# Epoch number 29
#  Current loss 0.3477959632873535

# %%
# Locate the test dataset and load it into the SiameseNetworkDataset
folder_dataset_test = datasets.ImageFolder(root="../../../organized_dataset_v7/dataset/test")
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transformation)
test_dataloader = DataLoader(siamese_dataset, num_workers=2, batch_size=1, shuffle=True)

# Grab one image that we are going to test
dataiter = iter(test_dataloader)
x0, _, _ = next(dataiter)

for i in range(10):
    # Iterate over 10 images and test them with the first image (x0)
    _, x1, label2 = next(dataiter)

    # Concatenate the two images together
    concatenated = torch.cat((x0, x1), 0)

    output1, output2 = net(x0.cuda(), x1.cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated), f'Dissimilarity: {euclidean_distance.item():.2f}')
