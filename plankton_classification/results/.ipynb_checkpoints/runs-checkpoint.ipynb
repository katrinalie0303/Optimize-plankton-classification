# %%
ls
# Out:
# dataset/   LICENSE  README.md         results/       runs.ipynb
# ds_utils/  models/  requirements.txt  result_utils/

# %%
run result_utils/main.py -d dataset/Baseline_Training_Set/test -m models/densenet/wandb/latest-run/files/model-best.h5
# Out:
# 2023-10-21 12:22:19.920479: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-21 12:22:24.703020: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1636] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 508 MB memory:  -> device: 0, name: Tesla V100-SXM3-32GB, pci bus id: 0000:36:00.0, compute capability: 7.0
# Found 2791 files belonging to 15 classes.
# 2023-10-21 12:22:30.802065: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8904
# ...
